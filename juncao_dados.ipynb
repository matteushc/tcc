# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diretorio_datasets = "/home/matteus-paula/Downloads/dados_tcc/municipio"
municipios = pd.read_csv(f'{diretorio_datasets}/municipio.csv', delimiter=";")

# %%
diretorio_datasets = "/home/matteus-paula/Downloads/dados_tcc/investimento"
investimento = pd.read_csv(f'{diretorio_datasets}/investimento_municipio.csv', delimiter=";")

# %%
diretorio_datasets = "/home/matteus-paula/Downloads/dados_tcc/ideb"
ideb = pd.read_csv(f'{diretorio_datasets}/ideb_final.csv', delimiter=";")

# %%
diretorio_datasets = "/home/matteus-paula/Downloads/dados_tcc/inep"
inep_escolas = pd.read_csv(f'{diretorio_datasets}/escolas_set.csv', delimiter=";")

# %%
diretorio_datasets = "/home/matteus-paula/Downloads/dados_tcc/dados_tratados_remun"
remun_docentes_media_mun = pd.read_csv(f'{diretorio_datasets}/remuneracao_media_docentes.csv', delimiter=";")
# Out:
#    CO_MUNICIPIO  CO_UF  VL_TOTAL
# 0        150796     15   1231.68
# 1        210550     21   1095.79
# 2        210594     21   1452.22
# 3        220900     22   1711.82
# 4        230120     23    700.00

# %% [markdown]
# <br>

# %%
all_escolas = pd.merge(inep_escolas, ideb, on='CO_MUNICIPIO', how='inner')
all_escolas.head()
# Out:
#    CO_MUNICIPIO  CO_UF  IN_AGUA_EXISTENTE  IN_AGUA_FILTRADA  \
# 0       1100015     11              100.0             100.0
# 1       1100023     11              100.0             100.0
# 2       1100031     11              100.0             100.0
# 3       1100049     11              100.0             100.0
# 4       1100056     11              100.0             100.0
#
#    IN_ESGOTO_EXISTENTE  IN_BIBLIOTECA_SALA_LEITURA  IN_BANHEIRO  \
# 0                94.12                       26.47        85.29
# 1               100.00                       68.42       100.00
# 2               100.00                       25.00        75.00
# 3                97.96                       40.82        97.96
# 4               100.00                       28.57       100.00
#
#    IN_REFEITORIO  IN_AUDITORIO  IN_COMPUTADOR  ...  IN_PATIO  IN_AREA_VERDE  \
# 0          23.53          0.00          52.94  ...     58.82           2.94
# ...

# %%
all_escolas_mun = pd.merge(all_escolas, municipios, left_on='CO_MUNICIPIO', right_on='CO_MUNICDV', how='inner')
all_escolas_mun.head()
# Out:
#    CO_MUNICIPIO  CO_UF  IN_AGUA_EXISTENTE  IN_AGUA_FILTRADA  \
# 0       1100015     11              100.0             100.0
# 1       1100023     11              100.0             100.0
# 2       1100031     11              100.0             100.0
# 3       1100049     11              100.0             100.0
# 4       1100056     11              100.0             100.0
#
#    IN_ESGOTO_EXISTENTE  IN_BIBLIOTECA_SALA_LEITURA  IN_BANHEIRO  \
# 0                94.12                       26.47        85.29
# 1               100.00                       68.42       100.00
# 2               100.00                       25.00        75.00
# 3                97.96                       40.82        97.96
# 4               100.00                       28.57       100.00
#
#    IN_REFEITORIO  IN_AUDITORIO  IN_COMPUTADOR  ...  IN_QUADRA_ESPORTES  \
# 0          23.53          0.00          52.94  ...               41.18
# 1          81.58         44.74         100.00  ...               68.42
# ...

# %%
all_escolas_remun_docentes = pd.merge(all_escolas_mun, remun_docentes_media_mun, left_on='CO_MUNICIP', right_on='CO_MUNICIPIO', how='inner')
all_escolas_remun_docentes.head()
# Out:
#    CO_MUNICIPIO_x  CO_UF_x  IN_AGUA_EXISTENTE  IN_AGUA_FILTRADA  \
# 0         1100015       11              100.0             100.0
# 1         1100023       11              100.0             100.0
# 2         1100031       11              100.0             100.0
# 3         1100049       11              100.0             100.0
# 4         1100056       11              100.0             100.0
#
#    IN_ESGOTO_EXISTENTE  IN_BIBLIOTECA_SALA_LEITURA  IN_BANHEIRO  \
# 0                94.12                       26.47        85.29
# 1               100.00                       68.42       100.00
# 2               100.00                       25.00        75.00
# 3                97.96                       40.82        97.96
# 4               100.00                       28.57       100.00
#
#    IN_REFEITORIO  IN_AUDITORIO  IN_COMPUTADOR  ...  NOTA_IDEB  UF  COD_UF  \
# 0          23.53          0.00          52.94  ...       4.35  RO      11
# ...

# %%
final = pd.merge(all_escolas_remun_docentes, investimento, left_on='CO_MUNICIP', right_on='CO_MUNICIPIO_IBGE', how='inner')
final.head()
# Out:
#    CO_MUNICIPIO_x  CO_UF_x  IN_AGUA_EXISTENTE  IN_AGUA_FILTRADA  \
# 0         1100015       11              100.0             100.0
# 1         1100023       11              100.0             100.0
# 2         1100031       11              100.0             100.0
# 3         1100049       11              100.0             100.0
# 4         1100056       11              100.0             100.0
#
#    IN_ESGOTO_EXISTENTE  IN_BIBLIOTECA_SALA_LEITURA  IN_BANHEIRO  \
# 0                94.12                       26.47        85.29
# 1               100.00                       68.42       100.00
# 2               100.00                       25.00        75.00
# 3                97.96                       40.82        97.96
# 4               100.00                       28.57       100.00
#
#    IN_REFEITORIO  IN_AUDITORIO  IN_COMPUTADOR  ...  CO_MUNICIPIO_y  CO_UF_y  \
# 0          23.53          0.00          52.94  ...          110001       11
# ...

# %%
final['VL_DESPESA_ED_POR_CID'] = final['VL_DESPESA_EMPENHADA_EDUCACAO'] / final['NUM_POPULACAO']
final['VL_RECEITA_ED_POR_CID'] = final['VL_RECEITA_ORCADA'] / final['NUM_POPULACAO']

# %%
final.head()
# Out:
#    CO_MUNICIPIO_x  CO_UF_x  IN_AGUA_EXISTENTE  IN_AGUA_FILTRADA  \
# 0         1100015       11              100.0             100.0
# 1         1100023       11              100.0             100.0
# 2         1100031       11              100.0             100.0
# 3         1100049       11              100.0             100.0
# 4         1100056       11              100.0             100.0
#
#    IN_ESGOTO_EXISTENTE  IN_BIBLIOTECA_SALA_LEITURA  IN_BANHEIRO  \
# 0                94.12                       26.47        85.29
# 1               100.00                       68.42       100.00
# 2               100.00                       25.00        75.00
# 3                97.96                       40.82        97.96
# 4               100.00                       28.57       100.00
#
#    IN_REFEITORIO  IN_AUDITORIO  IN_COMPUTADOR  ...  VL_TOTAL  \
# 0          23.53          0.00          52.94  ...   1766.74
# 1          81.58         44.74         100.00  ...   3571.33
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5205 entries, 0 to 5204
# Data columns (total 41 columns):
# CO_MUNICIPIO_x                   5205 non-null int64
# CO_UF_x                          5205 non-null int64
# IN_AGUA_EXISTENTE                5205 non-null float64
# IN_AGUA_FILTRADA                 5205 non-null float64
# IN_ESGOTO_EXISTENTE              5205 non-null float64
# IN_BIBLIOTECA_SALA_LEITURA       5205 non-null float64
# IN_BANHEIRO                      5205 non-null float64
# IN_REFEITORIO                    5205 non-null float64
# IN_AUDITORIO                     5205 non-null float64
# IN_COMPUTADOR                    5205 non-null float64
# IN_INTERNET                      5205 non-null float64
# IN_BANDA_LARGA                   5205 non-null float64
# IN_ALIMENTACAO                   5205 non-null float64
# IN_PATIO                         5205 non-null float64
# IN_AREA_VERDE                    5205 non-null float64
# ...

# %%
df_p_1 = final[['UF', 'IN_AGUA_EXISTENTE', 'IN_ESGOTO_EXISTENTE']].groupby('UF') \
            .agg(lambda x: round((x.sum() * 100) / x.count(), 2))
df_p_1.plot(kind='bar', figsize=(20,10))

# %%
df_p_2 = final[['UF', 'IN_COMPUTADOR', 'IN_INTERNET', 'IN_BANDA_LARGA']].groupby('UF') \
            .agg(lambda x: round((x.sum() * 100) / x.count(), 2))
df_p_2.plot(kind='bar', figsize=(20,10))

# %%
df_p_3 = final[['UF', 'IN_LABORATORIO_CIENCIAS', 'IN_LABORATORIO_INFORMATICA']].groupby('UF') \
            .agg(lambda x: round((x.sum() * 100) / x.count(), 2))
df_p_3.plot(kind='bar', figsize=(20,10))

# %%
df_p_4 = final[['UF', 'IN_BIBLIOTECA_SALA_LEITURA']].groupby('UF') \
            .agg(lambda x: round((x.sum() * 100) / x.count(), 2))
df_p_4.plot(kind='bar', figsize=(20,10))

# %%
df_p_5 = final[['UF', 'IN_QUADRA_ESPORTES', 'IN_PATIO', 'IN_AREA_VERDE']].groupby('UF') \
            .agg(lambda x: round((x.sum() * 100) / x.count(), 2))
df_p_5.plot(kind='bar', figsize=(20,10))

# %%
df_p_6 = final[['UF', 'NOTA_IDEB']].groupby('UF') \
            .mean()
df_p_6.plot(kind='bar', figsize=(20,10))

# %%
final[['CO_MUNICIPIO_x', 'CO_UF_x', 'IN_REFEITORIO', 'IN_ALIMENTACAO', 'IN_PATIO',
             'IN_BIBLIOTECA_SALA_LEITURA', 'IN_AUDITORIO',
             'IN_COMPUTADOR', 'IN_INTERNET', 'IN_AGUA_FILTRADA',
             'IN_BANDA_LARGA', 'IN_LABORATORIO_CIENCIAS', 
             'IN_LABORATORIO_INFORMATICA',
             'IN_QUADRA_ESPORTES','IN_BANHEIRO', 'IN_AREA_VERDE',
             'IN_DEPENDENCIAS_PNE', 'IN_ENERGIA_EXISTENTE',
             'IN_LIXO_RECICLA', 'VL_TOTAL', 'VL_DESPESA_ED_POR_CID', 'VL_RECEITA_ED_POR_CID']] \
            [(all_escolas['NOTA_IDEB'] > 5)].head()



# Notas abaixo de 5 - 29354
#         -> com internet 23.548 -     80%
#         -> laboratorio ciencias 4749 16%
#         -> com computador 27575      93% 
#         -> biblioteca leitura 19307  65%  
#         -> laboratorio info 17227    58%    
#         -> banda larga 18407         62%
#         -> quadra esporte 14550      49%
#         -> area verde 8365           28%


# Notas acima de 5 - 29734
#         -> com internet 28003         94%
#         -> laboratorio ciencias 3939  13%
#         -> com computador 29331       98%
#         -> biblioteca leitura 22906   77%
#         -> laboratorio info 20588     69%
#         -> banda larga 24099          81%
#         -> quadra esporte 19579       65%       
#         -> area verde 10367           34%

# ESTADOS: 23 (Ceara), 31 (Minas), 33 (Rio de Janeiro), 35 (Sao Paulo), 41 (Paraná), 
#   42 (Santa Catarina), 43 (Rio Grande do Sul), 52 (Goiás)

# Notas acima de 8 - 175
#         -> com internet 164
#         -> laboratorio ciencias 8
#         -> com computador 175
#         -> biblioteca leitura 132
#         -> laboratorio info 113
#         -> banda larga 120
#         -> quadra esporte 99
#         -> area verde 72

# Escolas Federais - 163 Nota >= 5 115 70%
# Escolas Estaduais - 19335 Nota >= 5 7782  40%
# Escolas municipais - 38743 Nota >= 5 21125 54%
# Escolas privadas - 847  Nota >= 5 712 84%
# Out:
# /home/matteus-paula/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#      CO_MUNICIPIO_x  CO_UF_x  IN_REFEITORIO  IN_ALIMENTACAO  IN_PATIO  \
# 13          1100148       11          50.00           100.0     90.00
# 397         1722107       17           7.69           100.0     61.54
# 443         2103109       21           0.00           100.0     52.63
# 721         2207934       22           0.00           100.0     75.00
# 901         2309003       23          16.67           100.0    100.00
#
#      IN_BIBLIOTECA_SALA_LEITURA  IN_AUDITORIO  IN_COMPUTADOR  IN_INTERNET  \
# 13                        50.00          0.00         100.00       100.00
# 397                       46.15         30.77          69.23        69.23
# 443                       10.53          0.00          31.58        31.58
# ...
