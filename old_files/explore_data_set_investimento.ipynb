# %%
diretorio_datasets = "/home/matteus-paula/Downloads/dados_tcc/investimento"

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# > ## Dados Investimento Municipio:<br>
# - Base de Investimentos dos Municipios
# - SIOPE (Sistema de Informações sobre Orçamentos Públicos em Educação)
# - https://www.fnde.gov.br/index.php/fnde_sistemas/siope/relatorios/arquivos-dados-analitico

# %%
investimento_edu = pd.read_csv(f'{diretorio_datasets}/DADOS_CONSOLIDADOS_2017.CSV', 
                            delimiter=";", encoding = "ISO-8859-1")
# Out:
# /home/matteus-paula/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
investimento_edu.head()
# Out:
#    #AN_EXERCICIO TP_PERIODO  NU_PERIODO  CO_UF              NO_UF  \
# 0           2017  BIMESTRAL           4     15               Para
# 1           2017      ANUAL           6     22              Piaui
# 2           2017  BIMESTRAL           1     43  Rio Grande do Sul
# 3           2017  BIMESTRAL           5     15               Para
# 4           2017      ANUAL           6     25            Paraiba
#
#   CO_MUNICIPIO_IBGE           NO_MUNICIPIO NO_ESFERA_ADM  \
# 0            150160                 Bonito     MUNICIPAL
# 1            220240      Capitão de Campos     MUNICIPAL
# 2            432143         Terra de Areia     MUNICIPAL
# 3            150720  São Domingos do Capim     MUNICIPAL
# 4            251140                  Picuí     MUNICIPAL
#
#   VL_RECEITA_PREVISAO_ATUALIZADA VL_RECEITA_REALIZADA  ...  \
# 0                    21855960,35          13418750,03  ...
# 1                    31938895,46          26555288,19  ...
# ...

# %%
investimento_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33333 entries, 0 to 33332
# Data columns (total 21 columns):
# #AN_EXERCICIO                     33333 non-null int64
# TP_PERIODO                        33333 non-null object
# NU_PERIODO                        33333 non-null int64
# CO_UF                             33333 non-null int64
# NO_UF                             33333 non-null object
# CO_MUNICIPIO_IBGE                 33333 non-null object
# NO_MUNICIPIO                      33333 non-null object
# NO_ESFERA_ADM                     33333 non-null object
# VL_RECEITA_PREVISAO_ATUALIZADA    33327 non-null object
# VL_RECEITA_REALIZADA              33327 non-null object
# VL_RECEITA_ORCADA                 33327 non-null object
# VL_DESPESA_DOTACAO_ATUALIZADA     33327 non-null object
# VL_DESPESA_EMPENHADA              33327 non-null object
# VL_DESPESA_LIQUIDADA              33327 non-null object
# VL_DESPESA_PAGA                   33327 non-null object
# ...

# %%
investimento_edu.describe()
# Out:
#        #AN_EXERCICIO    NU_PERIODO         CO_UF
# count        33333.0  33333.000000  33333.000000
# mean          2017.0      3.498395     32.399214
# std              0.0      1.707780      9.840588
# min           2017.0      1.000000     11.000000
# 25%           2017.0      2.000000     25.000000
# 50%           2017.0      3.000000     31.000000
# 75%           2017.0      5.000000     41.000000
# max           2017.0      6.000000     53.000000

# %%
investimento_edu[investimento_edu['VL_DESPESA_ORCADA_EDUCACAO'].isnull()]
# Out:
#        #AN_EXERCICIO TP_PERIODO  NU_PERIODO  CO_UF NO_UF CO_MUNICIPIO_IBGE  \
# 33088           2017  BIMESTRAL           2     15  Para            150470
# 33089           2017  BIMESTRAL           3     15  Para            150470
# 33090           2017      ANUAL           6     15  Para            150470
# 33100           2017  BIMESTRAL           4     15  Para            150470
# 33103           2017  BIMESTRAL           5     15  Para            150470
# 33156           2017  BIMESTRAL           1     15  Para            150470
#
#       NO_MUNICIPIO NO_ESFERA_ADM VL_RECEITA_PREVISAO_ATUALIZADA  \
# 33088         Moju     MUNICIPAL                            NaN
# 33089         Moju     MUNICIPAL                            NaN
# 33090         Moju     MUNICIPAL                            NaN
# 33100         Moju     MUNICIPAL                            NaN
# 33103         Moju     MUNICIPAL                            NaN
# ...

# %%
investimento_edu.dropna(inplace=True)
investimento_edu.reset_index(drop=True, inplace=True)

# %%
investimento_edu.CO_MUNICIPIO_IBGE.str.contains('\D', regex=True).tail()
# Out:
# 33322    True
# 33323    True
# 33324    True
# 33325    True
# 33326    True
# Name: CO_MUNICIPIO_IBGE, dtype: object

# %%
investimento_edu.iloc[33322]['CO_MUNICIPIO_IBGE']
# Out:
# 'NÃO SE APLIC'

# %%
investimento_edu = investimento_edu[investimento_edu['CO_MUNICIPIO_IBGE'] != 'NÃO SE APLIC']
investimento_edu.tail()
# Out:
#        #AN_EXERCICIO TP_PERIODO  NU_PERIODO  CO_UF           NO_UF  \
# 33178           2017  BIMESTRAL           3     33  Rio de Janeiro
# 33179           2017  BIMESTRAL           2     28         Sergipe
# 33180           2017  BIMESTRAL           1     28         Sergipe
# 33181           2017  BIMESTRAL           3     41          Parana
# 33182           2017      ANUAL           6     28         Sergipe
#
#       CO_MUNICIPIO_IBGE  NO_MUNICIPIO NO_ESFERA_ADM  \
# 33178            330412        Quatis     MUNICIPAL
# 33179            280410  Moita Bonita     MUNICIPAL
# 33180            280070  Brejo Grande     MUNICIPAL
# 33181            410890      Guairaçá     MUNICIPAL
# 33182            280510     Pedrinhas     MUNICIPAL
#
#       VL_RECEITA_PREVISAO_ATUALIZADA VL_RECEITA_REALIZADA  ...  \
# 33178                    56323172,98          29201840,68  ...
# 33179                    25000000,00           7540858,22  ...
# ...

# %%
investimento_edu.CO_MUNICIPIO_IBGE.str.contains('\D', regex=True).any()
# Out:
# False

# %%
investimento_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33183 entries, 0 to 33182
# Data columns (total 21 columns):
# #AN_EXERCICIO                     33183 non-null int64
# TP_PERIODO                        33183 non-null object
# NU_PERIODO                        33183 non-null int64
# CO_UF                             33183 non-null int64
# NO_UF                             33183 non-null object
# CO_MUNICIPIO_IBGE                 33183 non-null object
# NO_MUNICIPIO                      33183 non-null object
# NO_ESFERA_ADM                     33183 non-null object
# VL_RECEITA_PREVISAO_ATUALIZADA    33183 non-null object
# VL_RECEITA_REALIZADA              33183 non-null object
# VL_RECEITA_ORCADA                 33183 non-null object
# VL_DESPESA_DOTACAO_ATUALIZADA     33183 non-null object
# VL_DESPESA_EMPENHADA              33183 non-null object
# VL_DESPESA_LIQUIDADA              33183 non-null object
# VL_DESPESA_PAGA                   33183 non-null object
# ...

# %% [markdown]
# #### Convertendo virgula em ponto e transformando os valores em numerico

# %%
columns = ['VL_RECEITA_PREVISAO_ATUALIZADA','VL_RECEITA_REALIZADA',
           'VL_RECEITA_ORCADA', 'VL_DESPESA_DOTACAO_ATUALIZADA', 
           'VL_DESPESA_EMPENHADA', 'VL_DESPESA_LIQUIDADA', 
           'VL_DESPESA_PAGA', 'VL_DESPESA_ORCADA', 'VL_DOTACAO_ATUALIZADA_EDUCACAO',
           'VL_DESPESA_EMPENHADA_EDUCACAO', 'VL_DESPESA_LIQUIDADA_EDUCACAO', 
           'VL_DESPESA_PAGA_EDUCACAO', 'VL_DESPESA_ORCADA_EDUCACAO']

investimento_edu[columns] = investimento_edu[columns].apply(lambda x: x.str.replace(',', '.'))
investimento_edu[columns] = investimento_edu[columns].apply(lambda x: pd.to_numeric(x))

# %%
investimento_edu.head()
# Out:
#    #AN_EXERCICIO TP_PERIODO  NU_PERIODO  CO_UF              NO_UF  \
# 0           2017  BIMESTRAL           4     15               Para
# 1           2017      ANUAL           6     22              Piaui
# 2           2017  BIMESTRAL           1     43  Rio Grande do Sul
# 3           2017  BIMESTRAL           5     15               Para
# 4           2017      ANUAL           6     25            Paraiba
#
#   CO_MUNICIPIO_IBGE           NO_MUNICIPIO NO_ESFERA_ADM  \
# 0            150160                 Bonito     MUNICIPAL
# 1            220240      Capitão de Campos     MUNICIPAL
# 2            432143         Terra de Areia     MUNICIPAL
# 3            150720  São Domingos do Capim     MUNICIPAL
# 4            251140                  Picuí     MUNICIPAL
#
#    VL_RECEITA_PREVISAO_ATUALIZADA  VL_RECEITA_REALIZADA  ...  \
# 0                     21855960.35           13418750.03  ...
# 1                     31938895.46           26555288.19  ...
# ...

# %%
investimento_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33183 entries, 0 to 33182
# Data columns (total 21 columns):
# #AN_EXERCICIO                     33183 non-null int64
# TP_PERIODO                        33183 non-null object
# NU_PERIODO                        33183 non-null int64
# CO_UF                             33183 non-null int64
# NO_UF                             33183 non-null object
# CO_MUNICIPIO_IBGE                 33183 non-null object
# NO_MUNICIPIO                      33183 non-null object
# NO_ESFERA_ADM                     33183 non-null object
# VL_RECEITA_PREVISAO_ATUALIZADA    33183 non-null float64
# VL_RECEITA_REALIZADA              33183 non-null float64
# VL_RECEITA_ORCADA                 33183 non-null float64
# VL_DESPESA_DOTACAO_ATUALIZADA     33183 non-null float64
# VL_DESPESA_EMPENHADA              33183 non-null float64
# VL_DESPESA_LIQUIDADA              33183 non-null float64
# VL_DESPESA_PAGA                   33183 non-null float64
# ...

# %%
investimento = investimento_edu[investimento_edu['TP_PERIODO'] == 'ANUAL']

investimento = investimento[['CO_MUNICIPIO_IBGE', 'VL_RECEITA_REALIZADA', 
                             'VL_RECEITA_ORCADA', 'VL_DESPESA_EMPENHADA_EDUCACAO', 
                             'VL_DESPESA_LIQUIDADA_EDUCACAO','VL_DESPESA_PAGA_EDUCACAO', 
                             'VL_DESPESA_ORCADA_EDUCACAO']]
investimento.head()
# Out:
#     CO_MUNICIPIO_IBGE  VL_RECEITA_REALIZADA  VL_RECEITA_ORCADA  \
# 1              220240           26555288.19        34961735.00
# 4              251140           42127547.21        54587846.95
# 6              130040           39923203.89        44384800.00
# 985            353750           22625221.95        28246286.50
# 986            241010           25579472.39        38367382.00
#
#      VL_DESPESA_EMPENHADA_EDUCACAO  VL_DESPESA_LIQUIDADA_EDUCACAO  \
# 1                      12072331.38                    12032331.38
# 4                      16942221.31                    16490231.22
# 6                      13045344.02                    11645040.21
# 985                     7426978.36                     7426978.36
# 986                    10960327.88                    10934213.88
#
#      VL_DESPESA_PAGA_EDUCACAO  VL_DESPESA_ORCADA_EDUCACAO
# 1                 11923238.43                 12736635.33
# 4                 16195594.58                 18527066.86
# ...

# %%
investimento.count()
# Out:
# CO_MUNICIPIO_IBGE                5522
# VL_RECEITA_REALIZADA             5522
# VL_RECEITA_ORCADA                5522
# VL_DESPESA_EMPENHADA_EDUCACAO    5522
# VL_DESPESA_LIQUIDADA_EDUCACAO    5522
# VL_DESPESA_PAGA_EDUCACAO         5522
# VL_DESPESA_ORCADA_EDUCACAO       5522
# dtype: int64

# %%
#pd.options.display.float_format = '{:,.0f}'.format

# %%
investimento.to_csv(f'{diretorio_datasets}/investimento_municipio.csv', sep=';', encoding='utf-8', index=False)
